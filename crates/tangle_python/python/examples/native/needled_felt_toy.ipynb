# %% [markdown]
# # Six-layer educational needled felt
#
# The six deposition layers are generated together, sliced into detached collections, then inserted one at a time. Each deposited ply is lowered, released, randomly needled, and relaxed before the next insertion.

# %%
import needled_felt_toy as example
recipe, settings = example.build()
print(f"{len(recipe.operations())} recipe operations")
print(*recipe.operations()[:12], sep="\n")

# %% [markdown]
# The complete configuration matches the Rust example and is intentionally more expensive than the small notebooks.

# %%
RUN_FULL_RECIPE = False
result = example.run() if RUN_FULL_RECIPE else None
result
