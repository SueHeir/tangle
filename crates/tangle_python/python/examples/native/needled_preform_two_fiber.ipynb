# %% [markdown]
# # Physical-scale two-material needled preform
#
# This is the complete 2.5 mm periodic, six-layer configuration with fine 7 µm fibers (500 µm minimum bend radius) and coarse 19 µm fibers (60 µm minimum bend radius), staged layer approach, circular needling, adaptive segmentation, hard/soft solve policies, final compaction, and restart checkpoints.

# %%
import needled_preform_two_fiber as example
recipe, settings = example.build()
print(f"{len(recipe.operations())} recipe operations")
print(settings.adaptive_segmentation.to_dict())

# %% [markdown]
# This is a long-running scientific configuration. Checkpointing is enabled by `example.run()`, so an interrupted calculation can be continued with `example.run(resume=True)`.

# %%
RUN_FULL_RECIPE = False
RESUME = False
result = example.run(resume=RESUME) if RUN_FULL_RECIPE else None
result
