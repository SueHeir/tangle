# %% [markdown]
# # Modular fake-TPS formation
#
# This reproduces the Rust schedule: insert planar layers, repeatedly move and relax them, capture planar junctions, insert through-thickness fibers, capture tying junctions, then compact.

# %%
import fake_tps_formation as example
recipe, settings = example.build()
print(*recipe.operations(), sep="\n")

# %% [markdown]
# The recipe is inspectable ordinary data before execution. Uncomment the run by setting the guard after reviewing the operations and settings.

# %%
RUN_FULL_RECIPE = False
result = example.run() if RUN_FULL_RECIPE else None
result
