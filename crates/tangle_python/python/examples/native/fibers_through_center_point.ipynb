# %% [markdown]
# # Fibers through one point
#
# Python counterpart of the Rust `examples/fibers_through_center_point`. Eight straight rigid fibers begin at the cell center and separate through capsule contact projection.

# %%
import fibers_through_center_point as example
recipe, settings = example.build()
print(*recipe.operations(), sep="\n")
settings.to_dict()

# %% [markdown]
# `rigid_translation` preserves every centerline exactly. Only one translation per fiber is solved.

# %%
result = example.run()
result
