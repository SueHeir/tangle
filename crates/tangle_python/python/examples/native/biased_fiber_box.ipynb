# %% [markdown]
# # Biased fiber populations
#
# The exact native seeded generator is exposed to Python. This notebook includes isotropic 3D, four-layer planar, and x-aligned configurations, plus the configurable 800-fiber stress variant.

# %%
import biased_fiber_box as example
example.CASES

# %%
case_name = "planar_layered"
population = example.population_settings(case_name)
population

# %% [markdown]
# The ordinary tutorial uses 160 fibers. Set `STRESS_SIZE = True` to reproduce the native companion runner's 800-fiber default without changing the population statistics.

# %%
STRESS_SIZE = False
count = 800 if STRESS_SIZE else 160
result = example.run_case(case_name, count=count, segments=8, max_iterations=6_000 if STRESS_SIZE else 2_000)
result
